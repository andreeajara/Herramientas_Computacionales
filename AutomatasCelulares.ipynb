# %%
# %pylab inline
import matplotlib.pyplot as plt
from matplotlib import colors
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
L=252
l=502

# %%
x=np.zeros((L,l)) #matriz base

# %%
#regla 90
x[0][l/2]=1 #se modifica el valor de la "casilla" en la primera fila

#se hace un doble recorrido para modificar la línea siguiente, dependiendo de la anterior, con la regla 90 del autómata celular
for j in range(size(x[:,1])-2):
    for i in range(size(x[0,:])-2):
        if(x[j][i]==1 and x[j][i+1]==1 and x[j][i+2]==1):
            x[j+1][i+1]=0
        
        elif(x[j][i]==1 and x[j][i+1]==1 and x[j][i+2]==0):
            x[0][i+1]=1
        
        elif(x[j][i]==1 and x[j][i+1]==0 and x[j][i+2]==1):
            x[j+1][i+1]=0
        
        elif(x[j][i]==1 and x[j][i+1]==0 and x[j][i+2]==0):
            x[j+1][i+1]=1
    
        elif(x[j][i]==0 and x[j][i+1]==1 and x[j][i+2]==1):
            x[j+1][i+1]=1
        
        elif(x[j][i]==0 and x[j][i+1]==1 and x[j][i+2]==0):
            x[j+1][i+1]=0
        
        elif(x[j][i]==0 and x[j][i+1]==0 and x[j][i+2]==1):
            x[j+1][i+1]=1
        
        elif(x[j][i]==0 and x[j][i+1]==0 and x[j][i+2]==0):
            x[j+1][i+1]=0

# %%
cmap=colors.ListedColormap(['white','black'])
imshow(x, cmap=cmap)

# %%
y=np.zeros((300,200))

# %%
#regla 30
y[0][100]=1 #se modifica el valor de la "casilla" en la primera fila

#se hace un doble recorrido para modificar la línea siguiente, dependiendo de la anterior, con la regla 30 del autómata celular
for j in range(size(y[:,1])-2):
    for i in range(size(y[0,:])-2):
        if(y[j][i]==1 and y[j][i+1]==1 and y[j][i+2]==1):
            y[j+1][i+1]=0
        
        elif(y[j][i]==1 and y[j][i+1]==1 and y[j][i+2]==0):
            y[0][i+1]=0
        
        elif(y[j][i]==1 and y[j][i+1]==0 and y[j][i+2]==1):
            y[j+1][i+1]=0
        
        elif(y[j][i]==1 and y[j][i+1]==0 and y[j][i+2]==0):
            y[j+1][i+1]=1
    
        elif(y[j][i]==0 and y[j][i+1]==1 and y[j][i+2]==1):
            y[j+1][i+1]=1
        
        elif(y[j][i]==0 and y[j][i+1]==1 and y[j][i+2]==0):
            y[j+1][i+1]=1
        
        elif(y[j][i]==0 and y[j][i+1]==0 and y[j][i+2]==1):
            y[j+1][i+1]=1
        
        elif(y[j][i]==0 and y[j][i+1]==0 and y[j][i+2]==0):
            y[j+1][i+1]=0

# %%
cmap=colors.ListedColormap(['white','black'])
imshow(y, cmap=cmap)
